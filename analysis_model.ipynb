# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import warnings
warnings.filterwarnings('ignore')
sns.set(style='whitegrid')

# %%
df = pd.read_csv("AIML Dataset.csv")

# %%
df.head()
# Out:
#    step      type    amount  ... newbalanceDest  isFraud  isFlaggedFraud
# 0     1   PAYMENT   9839.64  ...            0.0        0               0
# 1     1   PAYMENT   1864.28  ...            0.0        0               0
# 2     1  TRANSFER    181.00  ...            0.0        1               0
# 3     1  CASH_OUT    181.00  ...            0.0        1               0
# 4     1   PAYMENT  11668.14  ...            0.0        0               0
#
# [5 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 6362620 entries, 0 to 6362619
# Data columns (total 11 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   step            int64
#  1   type            str
#  2   amount          float64
#  3   nameOrig        str
#  4   oldbalanceOrg   float64
#  5   newbalanceOrig  float64
#  6   nameDest        str
#  7   oldbalanceDest  float64
#  8   newbalanceDest  float64
#  9   isFraud         int64
#  10  isFlaggedFraud  int64
# dtypes: float64(5), int64(3), str(3)
# memory usage: 534.0 MB

# %%
df.columns
# Out:
# Index(['step', 'type', 'amount', 'nameOrig', 'oldbalanceOrg', 'newbalanceOrig',
#        'nameDest', 'oldbalanceDest', 'newbalanceDest', 'isFraud',
#        'isFlaggedFraud'],
#       dtype='str')

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %%
df["isFlaggedFraud"].value_counts()
# Out:
# isFlaggedFraud
# 0    6362604
# 1         16
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# step              0
# type              0
# amount            0
# nameOrig          0
# oldbalanceOrg     0
# newbalanceOrig    0
# nameDest          0
# oldbalanceDest    0
# newbalanceDest    0
# isFraud           0
# isFlaggedFraud    0
# dtype: int64

# %%
df.shape
# Out:
# (6362620, 11)

# %%
round((df["isFraud"].value_counts()[1]/df.shape[0])*100,2)
# Out:
# np.float64(0.13)

# %%
df['type'].value_counts().plot(kind='bar',title='Transaction types',color='skyblue')
# Out:
# <Axes: title={'center': 'Transaction types'}, xlabel='type'>

# %%
fraud_by_types = df.groupby('type')['isFraud'].mean().sort_values(ascending=False)
fraud_by_types.plot(kind='bar',title='Fraud rate by types',color='Yellow')
plt.ylabel('Fraud rate')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
df["amount"].describe()
# Out:
# count    6.362620e+06
# mean     1.798619e+05
# std      6.038582e+05
# min      0.000000e+00
# 25%      1.338957e+04
# 50%      7.487194e+04
# 75%      2.087215e+05
# max      9.244552e+07
# Name: amount, dtype: float64

# %%
df["amount"].describe().astype(int)
# Out:
# count     6362620
# mean       179861
# std        603858
# min             0
# 25%         13389
# 50%         74871
# 75%        208721
# max      92445516
# Name: amount, dtype: int64

# %%
sns.histplot(np.log1p(df['amount']),bins=100, kde=True,color='green')
plt.title("Transaction amount distribution(log scaled)")
plt.xlabel("Log (Amount+1)")
plt.show()

# %%
sns.boxplot(data=df[df["amount"]<50000], x="isFraud",y="amount")
plt.title("Amount Vs Fraud (Amount filtered under 50000)")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\seaborn\_base.py:1768, in categorical_order(vector, order)
#    1767 try:
# -> 1768     order = vector.cat.categories
#    1769 except (TypeError, AttributeError):
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\pandas\core\generic.py:6206, in NDFrame.__getattr__(self, name)
#    6205     return self[name]
# -> 6206 return object.__getattribute__(self, name)
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\pandas\core\accessor.py:230, in Accessor.__get__(self, obj, cls)
#     229     return self._accessor
# --> 230 return self._accessor(obj)
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\pandas\core\arrays\categorical.py:2978, in CategoricalAccessor.__init__(self, data)
#    2977 def __init__(self, data) -> None:
# -> 2978     self._validate(data)
#    2979     self._parent = data.values
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\pandas\core\arrays\categorical.py:2987, in CategoricalAccessor._validate(data)
#    2986 if not isinstance(data.dtype, CategoricalDtype):
# -> 2987     raise AttributeError("Can only use .cat accessor with a 'category' dtype")
#
# AttributeError: Can only use .cat accessor with a 'category' dtype
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 sns.boxplot(data=df[df["amount"]<50000], x="isFraud",y="amount")
#       2 plt.title("Amount Vs Fraud (Amount filtered under 50000)")
#       3 plt.show()
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\seaborn\categorical.py:1619, in boxplot(data, x, y, hue, order, hue_order, orient, color, palette, saturation, fill, dodge, width, gap, whis, linecolor, linewidth, fliersize, hue_norm, native_scale, log_scale, formatter, legend, ax, **kwargs)
#    1616 if p.var_types.get(p.orient) == "categorical" or not native_scale:
#    1617     p.scale_categorical(p.orient, order=order, formatter=formatter)
# -> 1619 p._attach(ax, log_scale=log_scale)
#    1621 # Deprecations to remove in v0.14.0.
#    1622 hue_order = p._palette_without_hue_backcompat(palette, hue_order)
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\seaborn\_base.py:1134, in VectorPlotter._attach(self, obj, allowed_types, log_scale)
#    1132             else:
#    1133                 order = None
# -> 1134             seed_data = categorical_order(seed_data, order)
#    1135         converter.update_units(seed_data)
#    1137 # -- Set numerical axis scales
#    1138
#    1139 # First unpack the log_scale argument
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\seaborn\_base.py:1771, in categorical_order(vector, order)
#    1768     order = vector.cat.categories
#    1769 except (TypeError, AttributeError):
# -> 1771     order = pd.Series(vector).unique()
#    1773     if variable_type(vector) == "numeric":
#    1774         order = np.sort(order)
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\pandas\core\series.py:2228, in Series.unique(self)
#    2163 def unique(self) -> ArrayLike:
#    2164     """
#    2165     Return unique values of Series object.
#    2166
#    (...)   2226     Categories (3, str): ['a' < 'b' < 'c']
#    2227     """
# -> 2228     return super().unique()
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\pandas\core\base.py:1157, in IndexOpsMixin.unique(self)
#    1154 values = self._values
#    1155 if not isinstance(values, np.ndarray):
#    1156     # i.e. ExtensionArray
# -> 1157     result = values.unique()
#    1158 else:
#    1159     result = algorithms.unique1d(values)  # type: ignore[assignment]
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\pandas\core\arrays\_mixins.py:232, in NDArrayBackedExtensionArray.unique(self)
#     231 def unique(self) -> Self:
# --> 232     new_data = unique(self._ndarray)
#     233     return self._from_backing_data(new_data)
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\pandas\core\algorithms.py:433, in unique(values)
#     327 @set_module("pandas")
#     328 def unique(values):
#     329     """
#     330     Return unique values based on a hash table.
#     331
#    (...)    431     Length: 3, dtype: complex128
#     432     """
# --> 433     return unique_with_mask(values)
#
# File d:\FraudDetectionSystem\FraudDetectionSystem\.venv\Lib\site-packages\pandas\core\algorithms.py:476, in unique_with_mask(values, mask)
#     474 table = hashtable(len(values))
#     475 if mask is None:
# --> 476     uniques = table.unique(values)
#     477     uniques = _reconstruct_data(uniques, original.dtype, original)
#     478     return uniques
#
# KeyboardInterrupt:

# %%
df["balanceDiffOrig"] = df["oldbalanceOrg"]-df["newbalanceOrig"]
df["balanceDiffDist"] = df["oldbalanceDest"]-df["newbalanceDest"]

# %%
(df["balanceDiffOrig"]<0).sum()
# Out:
# np.int64(1399253)

# %%
(df["balanceDiffDist"]<0).sum()
# Out:
# np.int64(2806464)

# %%
df.head(2)
# Out:
#    step     type   amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 0     1  PAYMENT  9839.64  C1231006815       170136.0       160296.36
# 1     1  PAYMENT  1864.28  C1666544295        21249.0        19384.72
#
#       nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 0  M1979787155             0.0             0.0        0               0
# 1  M2044282225             0.0             0.0        0               0
#
#    balanceDiffOrig  balanceDiffDist
# 0          9839.64              0.0
# 1          1864.28              0.0

# %%
frauds_per_step = df[df["isFraud"]==1]["step"].value_counts().sort_index()
plt.plot(frauds_per_step.index, frauds_per_step.values,label="Fraud per step")
plt.xlabel("Step (Time)")
plt.ylabel("Number of Frauds")
plt.title("Frauds over time")
plt.grid(True)
plt.show()

# %%
df.drop(columns="step",inplace=True)

# %%
df.head(3)
# Out:
#        type   amount     nameOrig  oldbalanceOrg  newbalanceOrig     nameDest  \
# 0   PAYMENT  9839.64  C1231006815       170136.0       160296.36  M1979787155
# 1   PAYMENT  1864.28  C1666544295        21249.0        19384.72  M2044282225
# 2  TRANSFER   181.00  C1305486145          181.0            0.00   C553264065
#
#    oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  balanceDiffOrig  \
# 0             0.0             0.0        0               0          9839.64
# 1             0.0             0.0        0               0          1864.28
# 2             0.0             0.0        1               0           181.00
#
#    balanceDiffDist
# 0              0.0
# 1              0.0
# 2              0.0

# %%
top_senders = df["nameOrig"].value_counts().head(10)

# %%
top_senders
# Out:
# nameOrig
# C2098525306    3
# C400299098     3
# C1999539787    3
# C1065307291    3
# C545315117     3
# C1976208114    3
# C1784010646    3
# C1530544995    3
# C1902386530    3
# C1677795071    3
# Name: count, dtype: int64

# %%
top_receivers = df["nameDest"].value_counts(10)

# %%
top_receivers
# Out:
# nameDest
# C1286084959    1.775998e-05
# C985934102     1.713131e-05
# C665576141     1.650264e-05
# C2083562754    1.603113e-05
# C248609774     1.587396e-05
#                    ...
# C1812552860    1.571680e-07
# C1470998563    1.571680e-07
# C1850423904    1.571680e-07
# C1881841831    1.571680e-07
# C2080388513    1.571680e-07
# Name: proportion, Length: 2722362, dtype: float64

# %%
fraud_users = df[df["isFraud"]==1]['nameOrig'].value_counts().head(10)
fraud_users
# Out:
# nameOrig
# C1305486145    1
# C840083671     1
# C1420196421    1
# C2101527076    1
# C137533655     1
# C1118430673    1
# C749981943     1
# C1334405552    1
# C467632528     1
# C1364127192    1
# Name: count, dtype: int64

# %%
fraud_types = df[df["type"].isin(["TRANSFER","CASH_OUT"])]

# %%
fraud_types.head()
# Out:
#         type     amount     nameOrig  oldbalanceOrg  newbalanceOrig  \
# 2   TRANSFER     181.00  C1305486145          181.0             0.0
# 3   CASH_OUT     181.00   C840083671          181.0             0.0
# 15  CASH_OUT  229133.94   C905080434        15325.0             0.0
# 19  TRANSFER  215310.30  C1670993182          705.0             0.0
# 24  TRANSFER  311685.89  C1984094095        10835.0             0.0
#
#        nameDest  oldbalanceDest  newbalanceDest  isFraud  isFlaggedFraud  \
# 2    C553264065             0.0            0.00        1               0
# 3     C38997010         21182.0            0.00        1               0
# 15   C476402209          5083.0        51513.44        0               0
# 19  C1100439041         22425.0            0.00        0               0
# 24   C932583850          6267.0      2719172.89        0               0
#
#     balanceDiffOrig  balanceDiffDist
# 2             181.0             0.00
# 3             181.0         21182.00
# 15          15325.0        -46430.44
# 19            705.0         22425.00
# 24          10835.0      -2712905.89

# %%
fraud_types["type"].value_counts()
# Out:
# type
# CASH_OUT    2237500
# TRANSFER     532909
# Name: count, dtype: int64

# %%
sns.countplot(data=fraud_types,x="type",hue="isFraud")
plt.title("Fraud distribution in Transfer and cash_out")
plt.show()

# %%
corr = df[["amount","oldbalanceOrg","newbalanceOrig","oldbalanceDest","newbalanceDest","isFraud"]].corr()

# %%
corr
# Out:
#                   amount  oldbalanceOrg  newbalanceOrig  oldbalanceDest  \
# amount          1.000000      -0.002762       -0.007861        0.294137
# oldbalanceOrg  -0.002762       1.000000        0.998803        0.066243
# newbalanceOrig -0.007861       0.998803        1.000000        0.067812
# oldbalanceDest  0.294137       0.066243        0.067812        1.000000
# newbalanceDest  0.459304       0.042029        0.041837        0.976569
# isFraud         0.076688       0.010154       -0.008148       -0.005885
#
#                 newbalanceDest   isFraud
# amount                0.459304  0.076688
# oldbalanceOrg         0.042029  0.010154
# newbalanceOrig        0.041837 -0.008148
# oldbalanceDest        0.976569 -0.005885
# newbalanceDest        1.000000  0.000535
# isFraud               0.000535  1.000000

# %%
sns.heatmap(corr,annot=True,cmap= "coolwarm",fmt=".2f")
plt.title("Correlation matrix")
plt.show()

# %%
zero_after_transfer = df[
    (df["oldbalanceOrg"]>0) &
    (df["newbalanceOrig"]==0) &
    (df["type"].isin(["TRANSFER","CASH_OUT"]))
]

# %%
len(zero_after_transfer)
# Out:
# 1188074

# %%
zero_after_transfer.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 zero_after_transfer.head()
#
# NameError: name 'zero_after_transfer' is not defined

# %%
df["isFraud"].value_counts()
# Out:
# isFraud
# 0    6354407
# 1       8213
# Name: count, dtype: int64

# %% [markdown]
# Feature engineering and train model

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer

# %%
df.head()
# Out:
#    step      type    amount  ... newbalanceDest  isFraud  isFlaggedFraud
# 0     1   PAYMENT   9839.64  ...            0.0        0               0
# 1     1   PAYMENT   1864.28  ...            0.0        0               0
# 2     1  TRANSFER    181.00  ...            0.0        1               0
# 3     1  CASH_OUT    181.00  ...            0.0        1               0
# 4     1   PAYMENT  11668.14  ...            0.0        0               0
#
# [5 rows x 11 columns]

# %%
df_model = df.drop(["nameOrig","nameDest","isFlaggedFraud"],axis=1)

# %%
df_model.head()
# Out:
#    step      type    amount  ...  oldbalanceDest  newbalanceDest  isFraud
# 0     1   PAYMENT   9839.64  ...             0.0             0.0        0
# 1     1   PAYMENT   1864.28  ...             0.0             0.0        0
# 2     1  TRANSFER    181.00  ...             0.0             0.0        1
# 3     1  CASH_OUT    181.00  ...         21182.0             0.0        1
# 4     1   PAYMENT  11668.14  ...             0.0             0.0        0
#
# [5 rows x 8 columns]

# %%
catagorical = ["type"]
numeric = ["amount","oldbalanceOrg","newbalanceOrig","oldbalanceDest","newbalanceDest"]

# %%
y = df_model["isFraud"]
X = df_model.drop("isFraud",axis=1)

# %%
X_train, X_test , y_train,y_test = train_test_split(X,y,test_size=0.3,stratify=y)

# %%
preprocessor = ColumnTransformer(
    transformers= [
        ("num",StandardScaler(),numeric),
        ("cat",OneHotEncoder(drop="first"),catagorical)
    ],
    remainder="drop"
)

# %%
pipeline = Pipeline([
    ("prep",preprocessor),
    ("clf",LogisticRegression(class_weight="balanced",max_iter=1000))
]
)

# %%
pipeline.fit(X_train,y_train)
# Out:
# Pipeline(steps=[('prep',
#                  ColumnTransformer(transformers=[('num', StandardScaler(),
#                                                   ['amount', 'oldbalanceOrg',
#                                                    'newbalanceOrig',
#                                                    'oldbalanceDest',
#                                                    'newbalanceDest']),
#                                                  ('cat',
#                                                   OneHotEncoder(drop='first'),
#                                                   ['type'])])),
#                 ('clf',
#                  LogisticRegression(class_weight='balanced', max_iter=1000))])

# %%
pipeline.predict(X_test)
# Out:
# array([0, 0, 1, ..., 0, 0, 0], shape=(1908786,))

# %%
y_pred = pipeline.predict(X_test)

# %%
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.94      0.97   1906322
#            1       0.02      0.95      0.04      2464
#
#     accuracy                           0.94   1908786
#    macro avg       0.51      0.95      0.51   1908786
# weighted avg       1.00      0.94      0.97   1908786

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[1800428,  105894],
#        [    122,    2342]])

# %%
pipeline.score(X_test,y_test) * 100
# Out:
# 94.44589388228958

# %%
import joblib

joblib.dump(pipeline,"fraud_detection_pipeline.pkl")
# Out:
# ['fraud_detection_pipeline.pkl']
